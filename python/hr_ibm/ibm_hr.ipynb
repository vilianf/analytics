# %%
# Análise exploratoria das razoes para saida de funcionarios da ibm
#Importando pacotes que serao usados
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carregando dados
df_original = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df_original.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
pd.set_option('display.max_columns', 100)

# %%
df_original.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#Removendo a coluna id, pois não contribui para a análise. Primeiro, conferir se há duplicidade
df_original['EmployeeNumber'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_limpo = df_original.drop('EmployeeNumber', axis = 1)
df_limpo.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          2  Life Sciences              1
# 1                 8          1  Life Sciences              1
# 2                 2          2          Other              1
# 3                 3          4  Life Sciences              1
# 4                 2          1        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
#Conferindo se há nulos e brancos
df_limpo.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
#  14  JobRole                   1470 non-null   object
#  15  JobSatisfaction           1470 non-null   int64
#  16  MaritalStatus             1470 non-null   object
#  17  MonthlyIncome             1470 non-null   int64
#  18  MonthlyRate               1470 non-null   int64
#  19  NumCompaniesWorked        1470 non-null   int64
#  20  Over18                    1470 non-null   object
#  21  OverTime                  1470 non-null   object
#  22  PercentSalaryHike         1470 non-null   int64
#  23  PerformanceRating         1470 non-null   int64
#  24  RelationshipSatisfaction  1470 non-null   int64
#  25  StandardHours             1470 non-null   int64
#  26  StockOptionLevel          1470 non-null   int64
#  27  TotalWorkingYears         1470 non-null   int64
#  28  TrainingTimesLastYear     1470 non-null   int64
#  29  WorkLifeBalance           1470 non-null   int64
#  30  YearsAtCompany            1470 non-null   int64
#  31  YearsInCurrentRole        1470 non-null   int64
#  32  YearsSinceLastPromotion   1470 non-null   int64
#  33  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(25), object(9)
# memory usage: 390.6+ KB

# %%
df_limpo['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#Removendo mais colunas
df_limpo = df_limpo.drop('EmployeeCount', axis = 1)
df_limpo.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 0  Female          94               3         2        Sales Executive
# 1    Male          61               2         2     Research Scientist
# 2    Male          92               2         1  Laboratory Technician
# 3  Female          56               3         1     Research Scientist
# 4    Male          40               3         1  Laboratory Technician
#
#    JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                4        Single           5993        19479
# 1                2       Married           5130        24907
# 2                3        Single           2090         2396
# 3                3       Married           2909        23159
# 4                2       Married           3468        16632
#
#    NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      Y      Yes                 11                  3
# 1                   1      Y       No                 23                  4
# 2                   6      Y      Yes                 15                  3
# 3                   1      Y      Yes                 11                  3
# 4                   9      Y       No                 12                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2

# %%
df_limpo = df_limpo.drop('StandardHours', axis = 1)
df_limpo.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 0  Female          94               3         2        Sales Executive
# 1    Male          61               2         2     Research Scientist
# 2    Male          92               2         1  Laboratory Technician
# 3  Female          56               3         1     Research Scientist
# 4    Male          40               3         1  Laboratory Technician
#
#    JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                4        Single           5993        19479
# 1                2       Married           5130        24907
# 2                3        Single           2090         2396
# 3                3       Married           2909        23159
# 4                2       Married           3468        16632
#
#    NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      Y      Yes                 11                  3
# 1                   1      Y       No                 23                  4
# 2                   6      Y      Yes                 15                  3
# 3                   1      Y      Yes                 11                  3
# 4                   9      Y       No                 12                  3
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                         1                 0                  8
# 1                         4                 1                 10
# 2                         2                 0                  7
# 3                         3                 0                  8
# 4                         4                 1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1               6                   4
# 1                      3                3              10                   7
# 2                      3                3               0                   0
# 3                      3                3               8                   7
# 4                      3                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
#Separando entre colaboradores que sairam e permaneceram
df_sairam = df_limpo.loc[df_limpo['Attrition'] ==  'Yes']
df_sairam.shape
# Out:
# (237, 32)

# %%
df_ficaram = df_limpo.loc[df_limpo['Attrition'] ==  'No']
df_ficaram.shape
# Out:
# (1233, 32)

# %%
df_sairam.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  \
# count  237.000000   237.000000        237.000000  237.000000
# mean    33.607595   750.362869         10.632911    2.839662
# std      9.689350   401.899519          8.452525    1.008244
# min     18.000000   103.000000          1.000000    1.000000
# 25%     28.000000   408.000000          3.000000    2.000000
# 50%     32.000000   699.000000          9.000000    3.000000
# 75%     39.000000  1092.000000         17.000000    4.000000
# max     58.000000  1496.000000         29.000000    5.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement    JobLevel  \
# count               237.000000  237.000000      237.000000  237.000000
# mean                  2.464135   65.573840        2.518987    1.637131
# std                   1.169791   20.099958        0.773405    0.940594
# min                   1.000000   31.000000        1.000000    1.000000
# 25%                   1.000000   50.000000        2.000000    1.000000
# 50%                   3.000000   66.000000        3.000000    1.000000
# 75%                   4.000000   84.000000        3.000000    2.000000
# max                   4.000000  100.000000        4.000000    5.000000
#
#        JobSatisfaction  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# count       237.000000     237.000000    237.000000          237.000000
# mean          2.468354    4787.092827  14559.308017            2.940928
# std           1.118058    3640.210367   7208.153264            2.678519
# min           1.000000    1009.000000   2326.000000            0.000000
# 25%           1.000000    2373.000000   8870.000000            1.000000
# 50%           3.000000    3202.000000  14618.000000            1.000000
# 75%           3.000000    5916.000000  21081.000000            5.000000
# max           4.000000   19859.000000  26999.000000            9.000000
#
#        PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# count         237.000000         237.000000                237.000000
# mean           15.097046           3.156118                  2.599156
# std             3.770294           0.363735                  1.125437
# min            11.000000           3.000000                  1.000000
# 25%            12.000000           3.000000                  2.000000
# 50%            14.000000           3.000000                  3.000000
# 75%            17.000000           3.000000                  4.000000
# max            25.000000           4.000000                  4.000000
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count        237.000000         237.000000             237.000000
# mean           0.527426           8.244726               2.624473
# std            0.856361           7.169204               1.254784
# min            0.000000           0.000000               0.000000
# 25%            0.000000           3.000000               2.000000
# 50%            0.000000           7.000000               2.000000
# 75%            1.000000          10.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count       237.000000      237.000000          237.000000
# mean          2.658228        5.130802            2.902954
# std           0.816453        5.949984            3.174827
# min           1.000000        0.000000            0.000000
# 25%           2.000000        1.000000            0.000000
# 50%           3.000000        3.000000            2.000000
# 75%           3.000000        7.000000            4.000000
# max           4.000000       40.000000           15.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count               237.000000            237.000000
# mean                  1.945148              2.852321
# std                   3.153077              3.143349
# min                   0.000000              0.000000
# 25%                   0.000000              0.000000
# 50%                   1.000000              2.000000
# 75%                   2.000000              5.000000
# max                  15.000000             14.000000

# %%
df_ficaram.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1233.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233   812.504461          8.915653     2.927007
# std       8.888360   403.208379          8.012633     1.027002
# min      18.000000   102.000000          1.000000     1.000000
# 25%      31.000000   477.000000          2.000000     2.000000
# 50%      36.000000   817.000000          7.000000     3.000000
# 75%      43.000000  1176.000000         13.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1233.000000  1233.000000     1233.000000  1233.000000
# mean                  2.771290    65.952149        2.770479     2.145985
# std                   1.071132    20.380754        0.692050     1.117933
# min                   1.000000    30.000000        1.000000     1.000000
# 25%                   2.000000    48.000000        2.000000     1.000000
# 50%                   3.000000    66.000000        3.000000     2.000000
# 75%                   4.000000    83.000000        3.000000     3.000000
# max                   4.000000   100.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# count      1233.000000    1233.000000   1233.000000          1233.00000
# mean          2.778589    6832.739659  14265.779400             2.64558
# std           1.093277    4818.208001   7102.260749             2.46009
# min           1.000000    1051.000000   2094.000000             0.00000
# 25%           2.000000    3211.000000   7973.000000             1.00000
# 50%           3.000000    5204.000000  14120.000000             2.00000
# 75%           4.000000    8834.000000  20364.000000             4.00000
# max           4.000000   19999.000000  26997.000000             9.00000
#
#        PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# count        1233.000000        1233.000000               1233.000000
# mean           15.231144           3.153285                  2.733982
# std             3.639511           0.360408                  1.071603
# min            11.000000           3.000000                  1.000000
# 25%            12.000000           3.000000                  2.000000
# 50%            14.000000           3.000000                  3.000000
# 75%            18.000000           3.000000                  4.000000
# max            25.000000           4.000000                  4.000000
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1233.000000        1233.000000            1233.000000
# mean           0.845093          11.862936               2.832928
# std            0.841985           7.760719               1.293585
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          16.000000               3.000000
# max            3.000000          38.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1233.000000     1233.000000         1233.000000
# mean          2.781022        7.369019            4.484185
# std           0.681907        6.096298            3.649402
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        6.000000            3.000000
# 75%           3.000000       10.000000            7.000000
# max           4.000000       37.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1233.000000           1233.000000
# mean                  2.234388              4.367397
# std                   3.234762              3.594116
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000

# %%
#Comparando entre quem saiu e quem permaneceu. Há diferença considerável de salários, conforme exposto no boxplot.
plt.figure(figsize = (8,5))
sns.boxplot(x=df_limpo['MonthlyIncome'], y=df_limpo['Attrition'], data=df_limpo, orient="h", notch=True, palette="summer")
plt.xlabel('Salário Mensal')
plt.ylabel('Saiu ou Não')
plt.title('Comparação de Salários entre Quem saiu e Permanece')
# Out:
# C:\Users\vilia\AppData\Local\Temp\ipykernel_14648\860995988.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df_limpo['MonthlyIncome'], y=df_limpo['Attrition'], data=df_limpo, orient="h", notch=True, palette="summer")
# Text(0.5, 1.0, 'Comparação de Salários entre Quem saiu e Permanece')

# %%
#Comparando distancia da casa para trabalho. Há uma clara relação que distância para o trabalho impacta na decisão para a saída do colaborador
plt.figure(figsize = (8,5))
sns.boxplot(x=df_limpo['DistanceFromHome'], y=df_limpo['Attrition'], data=df_limpo, notch=True, orient="h", palette="ocean")
plt.xlabel('Distância entre Casa e Trabalho')
plt.ylabel('Saiu ou Não')
plt.title('Comparação de Distância da Residência para o Escritório entre Quem saiu e Permanece')
# Out:
# C:\Users\vilia\AppData\Local\Temp\ipykernel_14648\1707246359.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df_limpo['DistanceFromHome'], y=df_limpo['Attrition'], data=df_limpo, notch=True, orient="h", palette="ocean")
# Text(0.5, 1.0, 'Comparação de Distância da Residência para o Escritório entre Quem saiu e Permanece')

# %%
#Comparando tempo da última promoção entre os dois grupos. Mostra relação que até dois anos após a promoção, há maior chance de saída
plt.figure(figsize = (8,5))
sns.boxplot(x=df_limpo['YearsSinceLastPromotion'], y=df_limpo['Attrition'], data=df_limpo, notch=True, orient="h", palette="cubehelix")
plt.xlabel('Anos Desde a Última Promoção')
plt.ylabel('Saiu ou Não')
plt.title('Comparação do Tempo da Última Promoção entre Quem saiu e Permanece')
# Out:
# C:\Users\vilia\AppData\Local\Temp\ipykernel_14648\2062060028.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df_limpo['YearsSinceLastPromotion'], y=df_limpo['Attrition'], data=df_limpo, notch=True, orient="h", palette="cubehelix")
# Text(0.5, 1.0, 'Comparação do Tempo da Última Promoção entre Quem saiu e Permanece')

# %%
#Comparando tempo com o atual gestor.
plt.figure(figsize = (8,5))
sns.boxplot(x=df_limpo['YearsWithCurrManager'], y=df_limpo['Attrition'], data=df_limpo, notch=True, orient="h", palette="YlOrRd")
plt.xlabel('Anos com o Mesmo Gestor')
plt.ylabel('Saiu ou Não')
plt.title('Comparação do Tempo com o Atual Gestor entre Quem saiu e Permanece')
# Out:
# C:\Users\vilia\AppData\Local\Temp\ipykernel_14648\548502788.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df_limpo['YearsWithCurrManager'], y=df_limpo['Attrition'], data=df_limpo, notch=True, orient="h", palette="YlOrRd")
# Text(0.5, 1.0, 'Comparação do Tempo com o Atual Gestor entre Quem saiu e Permanece')

# %%
df_limpo.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 0  Female          94               3         2        Sales Executive
# 1    Male          61               2         2     Research Scientist
# 2    Male          92               2         1  Laboratory Technician
# 3  Female          56               3         1     Research Scientist
# 4    Male          40               3         1  Laboratory Technician
#
#    JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                4        Single           5993        19479
# 1                2       Married           5130        24907
# 2                3        Single           2090         2396
# 3                3       Married           2909        23159
# 4                2       Married           3468        16632
#
#    NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      Y      Yes                 11                  3
# 1                   1      Y       No                 23                  4
# 2                   6      Y      Yes                 15                  3
# 3                   1      Y      Yes                 11                  3
# 4                   9      Y       No                 12                  3
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                         1                 0                  8
# 1                         4                 1                 10
# 2                         2                 0                  7
# 3                         3                 0                  8
# 4                         4                 1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1               6                   4
# 1                      3                3              10                   7
# 2                      3                3               0                   0
# 3                      3                3               8                   7
# 4                      3                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
df_limpo['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
#Busca de relação entre área de estudo. Não há grandes diferenças entre os grupos, indicando que isso não influencia para permanência ou não
plt.figure(figsize = (12,6))

# Countplot
sns.countplot(x=df_sairam['EducationField'], data=df_sairam, palette="OrRd_r")
plt.ylabel('Education Field')             
plt.xlabel('\nQuantidade de Colaboradores\n')
plt.title('\nQuantidade de Colaboradores por Área de Estudo que Saíram\n')
plt.show()

plt.figure(figsize = (12,6))
sns.countplot(x=df_ficaram['EducationField'], data=df_sairam, palette="autumn")
plt.ylabel('Education Field')             
plt.xlabel('\nQuantidade de Colaboradores\n')
plt.title('\nQuantidade de Colaboradores por Área de Estudo de que Permanecem\n')
plt.show()
# Out:
# C:\Users\vilia\AppData\Local\Temp\ipykernel_14648\1733083631.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_sairam['EducationField'], data=df_sairam, palette="OrRd_r")
# C:\Users\vilia\AppData\Local\Temp\ipykernel_14648\1733083631.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_ficaram['EducationField'], data=df_sairam, palette="autumn")

# %%
#Comparando Nota de Satisfaço no Trabalho entre os dois grupos.Boxplot mostra forte relação entre notas e saída de colaboradores
plt.figure(figsize = (8,5))
sns.boxplot(x=df_limpo['JobSatisfaction'], hue=df_limpo['Attrition'] ,data=df_limpo, orient="h", palette="nipy_spectral_r")
plt.xlabel('Notas de 1 a 5 em Relação a Satisfação no Trabalho')
plt.ylabel('Saiu ou Não')
plt.title('Comparação Em Relação Nota de Satisfação no Trabalho e Saída da Empresa')
# Out:
# Text(0.5, 1.0, 'Comparação Em Relação Nota de Satisfação no Trabalho e Saída da Empresa')

# %%
#Verificar se a frequência de viagens influencia na saída de colaboradores
df_ficaram.shape
# Out:
# (1233, 32)

# %%
df_sairam.shape
# Out:
# (237, 32)

# %%
df_sairam['BusinessTravel'].value_counts(normalize=True) * 100
# Out:
# BusinessTravel
# Travel_Rarely        65.822785
# Travel_Frequently    29.113924
# Non-Travel            5.063291
# Name: proportion, dtype: float64

# %%
df_ficaram['BusinessTravel'].value_counts(normalize=True) * 100
# Out:
# BusinessTravel
# Travel_Rarely        71.938362
# Travel_Frequently    16.869424
# Non-Travel           11.192214
# Name: proportion, dtype: float64

# %%
#Há um aumento de 16 para 29% em caso que há viagens frequentes. Nos demais, sem grandes variações. Pode-se concluir que viagens frequentes é um dos fatores que contribuem para saída de colaboradores

# %%
df_limpo.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 0  Female          94               3         2        Sales Executive
# 1    Male          61               2         2     Research Scientist
# 2    Male          92               2         1  Laboratory Technician
# 3  Female          56               3         1     Research Scientist
# 4    Male          40               3         1  Laboratory Technician
#
#    JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                4        Single           5993        19479
# 1                2       Married           5130        24907
# 2                3        Single           2090         2396
# 3                3       Married           2909        23159
# 4                2       Married           3468        16632
#
#    NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      Y      Yes                 11                  3
# 1                   1      Y       No                 23                  4
# 2                   6      Y      Yes                 15                  3
# 3                   1      Y      Yes                 11                  3
# 4                   9      Y       No                 12                  3
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                         1                 0                  8
# 1                         4                 1                 10
# 2                         2                 0                  7
# 3                         3                 0                  8
# 4                         4                 1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1               6                   4
# 1                      3                3              10                   7
# 2                      3                3               0                   0
# 3                      3                3               8                   7
# 4                      3                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
#Analisando gênero. Não há mudanças consideráveis
df_ficaram['Gender'].value_counts(normalize=True) * 100
# Out:
# Gender
# Male      59.367397
# Female    40.632603
# Name: proportion, dtype: float64

# %%
df_sairam['Gender'].value_counts(normalize=True) * 100
# Out:
# Gender
# Male      63.291139
# Female    36.708861
# Name: proportion, dtype: float64

# %%
#Comparando quantidade de empresas em que o colaborador já trabalhou. Há uma pequena tendência de quem trabalha em mais empresas sair
sns.barplot(x='Attrition', y='NumCompaniesWorked', data=df_limpo, estimator=np.mean)
plt.title("Média de Porcentagem de Crescimento Salarial")
plt.show()

# %%
#Verificando se a realização de horas extras é fator contribuinte

sns.countplot(data=df_limpo, x='OverTime', hue='Attrition')
plt.title("Tabela de Horas Extras entre Quem Saiu e Ficou")
plt.show()

# %%
df_sairam['OverTime'].value_counts(normalize=True) * 100
# Out:
# OverTime
# Yes    53.586498
# No     46.413502
# Name: proportion, dtype: float64

# %%
df_ficaram['OverTime'].value_counts(normalize=True) * 100
# Out:
# OverTime
# No     76.561233
# Yes    23.438767
# Name: proportion, dtype: float64

# %%
#A realização de horas extras é um dos fatores contribuintes para saída de funcionários

# %%
#Analisando setores
df_limpo['Department'].value_counts(normalize=True) * 100
# Out:
# Department
# Research & Development    65.374150
# Sales                     30.340136
# Human Resources            4.285714
# Name: proportion, dtype: float64

# %%
df_sairam['Department'].value_counts(normalize=True) * 100
# Out:
# Department
# Research & Development    56.118143
# Sales                     38.818565
# Human Resources            5.063291
# Name: proportion, dtype: float64

# %%
#Departamento de Vendas há saídas acima do proporcional do quadro de colaboradores

# %%
#Comparando idade, Estado Civil
sns.boxplot(data=df_limpo, x="Attrition", y="Age", hue="MaritalStatus", notch=True, palette="pastel")
plt.show()
